# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests

#fetching the webpage content
url = 'https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000401'

response = requests.get(url)
html_content = response.content

#Parsing HTML content with BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")

#Extracting specific elements
table = soup.find(id='simpleTable')
print(html_content.decode('utf-8'))
if table:
    #do something with the table
    #extract the data and template/print it
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        for cell in cells:
            print(cell.text)
else:
    print("Table not found")
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en" dir="ltr"
#       xmlns="http://www.w3.org/1999/xhtml">
# <head>
#     <meta charset="utf-8">
#     <base href="https://www150.statcan.gc.ca/t1/tbl1/" />
#
#     <title>
#         Consumer Price Index, monthly, not seasonally adjusted</title>
#     <link rel="schema.dcterms" href="http://purl.org/dc/terms/"/>
#     <meta name="description" content="Monthly indexes for major components and special aggregates of the Consumer Price Index (CPI), not seasonally adjusted, for Canada, provinces, Whitehorse, Yellowknife and Iqaluit. Data are presented for the current month and previous four months. The base year for the index is 2002=100." />
#         <meta name="keywords" content="Municipal and local data" />
#     <meta name="dcterms.title" content="Consumer Price Index, monthly, not seasonally adjusted"/>
#     <meta name="dcterms.language" title="ISO639-2/T" content="eng" />
#     <meta name="dcterms.issued" title="W3CDTF" content="2007-06-19" />
#         <meta name="dcterms.modified" title="W3CDTF" content="2024-08-20" />
#     <meta name="dcterms.subject" title="gcstc" content="none" />
#     <meta name="dcterms.creator" content="Government of Canada, Statistics Canada" />
#     <meta name="robots" content="index,nofollow,noarchive" />
#     <meta content="width=device-width,initial-scale=1" name="viewport" />
#     <meta property="dcterms:service" content="StatCan"/>
#     <meta property="dcterms:accessRights" content="2"/>
#
#     <link rel="canonical" href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000401" />
#
#     <link href="/t1/wet-boew4b/assets/favicon.ico" rel="icon" type="image/x-icon">
#     <link rel="stylesheet" href="/t1/wet-boew4b/css/wet-boew.min.css">
#     <script src="/t1/wet-boew4b/js/jquery.min.js"></script>
#     <link rel="stylesheet" href="/t1/wet-boew4b/css/theme.min.css">
#     <link rel="stylesheet" href="/t1/wet-boew4b/css/statcan.css">
#
#     <!--[if lt IE 9]>
#     <link href="/t1/wet-boew4b/assets/favicon.ico" rel="shortcut icon" />
#     <link rel="stylesheet" href="/t1/wet-boew4b/css/ie8-wet-boew.min.css" />
#     <![endif]-->
#
#     <link rel="stylesheet" href="/t1/wet-boew4b/invitation-manager/Overlay.css">
#
#     <noscript><link rel="stylesheet" href="/t1/wet-boew4b/css/noscript.min.css" /></noscript>
#     <script src="https://assets.adobedtm.com/be5dfd287373/8cdb3d539c44/launch-6df9e9b447f9.min.js" crossorigin="anonymous"></script>
#     <script>dataLayer1 = [];</script>
#     <script src="resources/js/support/lodash/lodash.min.js"></script>
#
#     <script src="resources/js/custom/jsDate.js"></script>
#     <script src="resources/js/applyButtond2178e7916b7389bbf38de58bb712713af78f498.js" type="text/javascript"></script>
#     <script src="resources/js/sharedJSd2178e7916b7389bbf38de58bb712713af78f498.js" type="text/javascript"></script>
#
#     <script src="resources/js/dataTable/jquery.dataTables.min.js"></script>
#     <script src="resources/js/dataTable/plugins/natural.sorting.js"></script>
#     <script src="resources/js/dataTable/plugins/formatted-numbers.js"></script>
#     <link href="resources/css/custom/tabs.css" rel="stylesheet" />
#     <link href="resources/css/custom/correction.css" rel="stylesheet" />
#     <link href="resources/css/pubsd2178e7916b7389bbf38de58bb712713af78f498.css" media="all" rel="stylesheet" type="text/css" />
#     <link href="resources/css/general.css"  rel="stylesheet" />
#     <link href="resources/font-awesome/css/font-awesome.min.css"  rel="stylesheet" />
#     <meta name="format-detection" content="telephone=no">
# </head>
#
# <body vocab="http://schema.org/" typeof="WebPage">
# <ul id="wb-tphp">
# <li class="wb-slc">
# <a class="wb-sl" href="#wb-cont">Skip to main content</a>
# </li>
# <li class="wb-slc visible-sm visible-md visible-lg">
# <a class="wb-sl" href="#wb-info">Skip to "About this site"</a>
# </li>
# </ul>
# <header role="banner">
# <div id="wb-bnr" class="container">
# <section id="wb-lng" class="visible-md visible-lg text-right">
# <h2 class="wb-inv">Language selection</h2>
# <div class="row">
# <div class="col-md-12">
# <ul class="list-inline margin-bottom-none">
# <li><a lang="fr" href="https://www150.statcan.gc.ca/t1/tbl1/fr/tv.action?pid=1810000401&amp;request_locale=fr">Fran&#231;ais</a></li>
# </ul>
# </div>
# </div>
# </section>
# <div class="row">
# <div class="brand col-xs-8 col-sm-9 col-md-6">
# <a href="https://www.statcan.gc.ca/en/start" property="URL"><img src="/t1/wet-boew4b/assets/sig-blk-en.svg" alt="Statistics Canada"><span class="wb-inv"> / <span lang="fr">Statistique Canada</span></span></a>
# </div>
# <section class="wb-mb-links col-xs-4 col-sm-3 visible-sm visible-xs" id="wb-glb-mn">
# <h2>Search and menus</h2>
# <ul class="list-inline text-right chvrn">
# <li><a href="#mb-pnl" title="Search and menus" aria-controls="mb-pnl" class="overlay-lnk" role="button"><span class="glyphicon glyphicon-search"><span class="glyphicon glyphicon-th-list"><span class="wb-inv">Search and menus</span></span></span></a></li>
# </ul>
# <div id="mb-pnl"></div>
# </section>
#
# <section id="wb-srch" class="col-xs-6 text-right visible-md visible-lg">
# <h2 class="wb-inv">Search</h2>
# <form action="https://www.statcan.gc.ca/search/results/site-search" method="get" name="cse-search-box" role="search" class="form-inline">
# <div class="form-group wb-srch-qry">
# <label for="wb-srch-q" class="wb-inv">Search website</label>
# <input type="hidden" name="fq" value="stclac:2" />
# <input id="wb-srch-q" list="wb-srch-q-ac" class="wb-srch-q form-control" name="q" type="search" value="" size="27" maxlength="150" placeholder="Search website">
# <datalist id="wb-srch-q-ac">
# </datalist>
# </div>
# <div class="form-group submit">
# <button type="submit" id="wb-srch-sub" class="btn btn-primary btn-small" name="wb-srch-sub"><span class="glyphicon-search glyphicon"></span><span class="wb-inv">Search</span></button>
# </div>
# </form>
# </section>
# </div>
# </div>
#
# <nav role="navigation" id="wb-sm" class="wb-menu visible-md visible-lg" data-trgt="mb-pnl" data-ajax-replace="/t1/wet-boew4b/ajax/sitemenu-en.html" typeof="SiteNavigationElement">
# 	<div class="container nvbar">
# 		<h2 class="wb-inv">Topics menu</h2>
# 		<div class="row">
# 			<ul class="list-inline menu">
# 				<li><a href="https://www150.statcan.gc.ca/n1/en/subjects?MM=1">Subjects</a></li>
# 				<li><a href="https://www150.statcan.gc.ca/n1/en/type/data?MM=1">Data</a></li>
# 				<li><a href="https://www150.statcan.gc.ca/n1/en/type/analysis?MM=1">Analysis</a></li>
# 				<li><a href="https://www150.statcan.gc.ca/n1/en/type/reference?MM=1">Reference</a></li>
# 				<li><a href="https://www.statcan.gc.ca/en/geography?MM=1">Geography</a></li>
# 				<li><a href="https://www.statcan.gc.ca/en/census?MM=1">Census</a></li>
# 				<li><a href="https://www.statcan.gc.ca/en/surveys?MM=1">Surveys and statistical programs</a></li>
# 				<li><a href="https://www.statcan.gc.ca/en/about/statcan?MM=1">About StatCan</a></li>
# 				<li><a href="https://www.canada.ca/en.html">Canada.ca</a></li>
# 			</ul>
# 		</div>
# 	</div>
# </nav>
#
# <nav role="navigation" id="wb-bc" class="" property="breadcrumb">
# 	<div class="container">
# 		<div class="row"><ol class="breadcrumb">
#         <li><a href="https://www150.statcan.gc.ca/n1/en" rel='up'>Home</a></li>
#             <li><a href="https://www150.statcan.gc.ca/n1/en/type/data?MM=1#tables" rel='up'>Data</a></li>
#         </ol>
# </div>
# </div>
# </nav>
# </header>
#
# <main role="main" property="mainContentOfPage" class="container"><style type="text/css">
#     .tv-loader {
#         width		:	100%;
#         height		: 	100%;
#         position	:   absolute;
#         top			:	0px;
#         left		:	0px;
#
#     }
#
#     .tv-loader .tv-loader-image {
#         width		:	100%;
#         height		: 	100%;
#         margin		:	0;
#         padding		:	0;
#         background	: 	rgba(255,255,255,0.5) url('resources/css/BigLoader.gif') no-repeat center top;
#         /*background-size:  30px 30px;*/
#         position	:	absolute;
#         z-index		:	999;
#     }
# </style>
#
# <div id="tv-loader" class="tv-loader">
#     <div class="tv-loader-image" >
#     </div>
# </div>
#
# <script>
#     $(window).on('load', function(){
#         $('#tv-loader').fadeOut(1000);
#     })
#
#     $(document).ready(function () {
#         $(".tbl-loader").click(function (event) {
#             $('#tv-loader').show();
#         });
#     });
# </script>
#
# <script type="text/javascript">
#   $(document).ready(function () {
#     $('#close-alert-security-btn').click(function (e) {
#      var url = '/tbl1/en/tv!closeSecurityBanner-nonTraduit.action';
#       $.ajax({
#         url: url,
#         type: 'GET',
#         async : false,
#         cache: false,
#         success: function (data, textStatus, jqXHR) {
#         },
#         error: function (jqXHR, textStatus, errorThrown) {
#           console.log("an error was occurred" + textStatus);
#         }
#       });
# //
#       e.preventDefault();
#       $('#securityBanner').remove();
#
#
#     })
#   });
# </script>
# <script>
#     let action = 'tv';
#     viewObjects = {};
# </script>
#
# <h1 id="wb-cont" style="margin-top: 0em;">
#     Consumer Price Index, monthly, not seasonally adjusted<sup id='title-footnote-id'><a href="#Footnote1" aria-controls="centred-popup" class="wb-lbx" role="button" aria-label="Footnote 1">1</a>, <a href="#Footnote2" aria-controls="centred-popup" class="wb-lbx" role="button" aria-label="Footnote 2">2</a>, <a href="#Footnote3" aria-controls="centred-popup" class="wb-lbx" role="button" aria-label="Footnote 3">3</a></sup></h1>
# <div class="clearfix">
#     <div class="row">
#         <div class="col-md-8 mrgn-btm-0 mrgn-lft-0 divLeft">
#             <div class="font-small color-medium line-height-medium pull-left">
#                 <p class="viewSubtitle">
#                     Frequency:&nbsp;Monthly</p>
#                 <p class="viewSubtitle">
#                     Table:
#                     18-10-0004-01
#                         (formerly CANSIM&nbsp;326-0020)
#                     </p>
#                 <p class="viewSubtitle">
#                     Release date:
#                     2024-08-20</p>
#                 <p class="viewSubtitle">
#     <em>Geography:</em>
#         Canada, Province or territory, Census subdivision, Census metropolitan area, Census metropolitan area part</p>
# <p class="viewSubtitle">
#     </p>
# <p class="viewSubtitle">
#     </p>
#
# </div>
#         </div>
#         <div class="col-md-4 mrgn-btm-0 mrgn-lft-0 divRight">
#             <div class="pull-right">
#                 <div row class="font-small color-medium line-height-medium" style="text-align: right;">
#                     <p>
#                         <a href="https://www.statcan.gc.ca/eng/about/website-help">
#                             <span class="glyphicon glyphicon-question-sign"></span>
#                             Help</a>
#                     </p>
#                 </div>
#                     <p>
#     <button type="button" class="btn btn-default bookmarktooltip tooltipstered" id="bookmarktooltip">
#         <i class="fa fa-bookmark"></i>
#         Save my customizations</button>
# </p>
#
# <!-- Add content to the popup -->
# <div style="">
#     <div id="bookmark-content" class="bookmark-content" style="display: none;">
#         <div class="input-group">
#             <input id="bookmarkUrl" type="text" style="margin-bottom: 0.5em;" class="form-control" value=""/>
#             <span class="input-group-btn">
#                 <button class="btn bookmarkBtn" data-clipboard-action="copy" data-clipboard-target="#bookmarkUrl">
#                     <i class="fa fa-copy"></i>
#                 </button>
#             </span>
#         </div>
#     </div>
# </div>
#
# <script type='text/javascript'>
#
#     $(document).ready(function () {
#
#
#         $('#bookmarkUrl').val(document.URL);
#
#         $('.bookmarktooltip').tooltipster({
#             contentAsHTML: 'true',
#             theme: 'tooltipster-light',
#             trigger: 'click',
#             side: 'bottom',
#             interactive: true,
#             content: $( this ).find( '.bookmark-content' ).show(),
#             maxWidth: 500
#         });
#         new ClipboardJS('.bookmarkBtn');
#         $('#bookmarktooltip').click();
#         $('.bookmarktooltip').tooltipster('hide');
#
#     });
#
#     function reloadSaveMySelections(bookmarkUrl) {
#         // reload bookmark info.
#         $(".bookmarktooltip").tooltipster('destroy');
#         // remove duplicated characters.
#         let pathname = window.location.pathname.replace("cv!recreate.action", "");
#         pathname = pathname.replace("cv.action", "");
#         pathname = pathname.replace("cv", "");
#         let bookmarkUrlValue = window.location.origin + pathname + bookmarkUrl;
#         new ClipboardJS('.bookmarkBtn');
#         $(".bookmarktooltip").tooltipster({
#             contentAsHTML: 'true',
#             theme: 'tooltipster-light',
#             trigger: 'click',
#             side: 'bottom',
#             interactive: true,
#             maxWidth: 500,
#             content: '<div class="input-group"><input id="bookmarkUrl" type="text" style="margin-bottom: 0.5em;"'+
#                 ' class="form-control" value="'+ bookmarkUrlValue + '"/>' +
#                 '<span class="input-group-btn"><button class="btn bookmarkBtn" data-clipboard-action="copy" data-clipboard-target="#bookmarkUrl">' +
#                 '<i class="fa fa-copy"></i></button></span></div>'
#         });
#         new ClipboardJS('.bookmarkBtn');
#         return bookmarkUrlValue;
#     }
#
# </script>
# <link rel="stylesheet" href="resources/js/support/tooltip/tooltipster.bundle.min.css" />
# <link rel="stylesheet" href="resources/js/support/tooltip/tooltipster-sideTip-light.min.css" />
# <script src="resources/js/support/tooltip/tooltipster.bundle.min.js"></script>
# <script src="resources/js/support/tooltip/clipboard.min.js"></script></div>
#         </div>
#     </div>
# </div>
# <form id="viewForm" name="simpleView" action="/t1/tbl1/en/tv.action" method="get" class="form-horizontal background-light" style="margin-bottom: 1em;">
# <input aria-hidden="true" type="hidden" value='1810000401' name="pid" id="pid"/>
#     <div id="errorMsg" class="hide">
#         <div class="module-alert span-8">
#             <div class="errorMessage indent-medium margin-right-medium">
#                 <ul>
#                     <li id="errorMsgText"></li>
#                 </ul>
#             </div>
#         </div>
#     </div>
#
#     <link rel="stylesheet" type="text/css" href="resources/css/simpleView/timeFramed2178e7916b7389bbf38de58bb712713af78f498.css">
# <script src="resources/js/simpleView/timeFramed2178e7916b7389bbf38de58bb712713af78f498.js"></script>
# <details open="open">
#     <summary class="forH3FontSize">
#         Customize table</summary>
#
#     <div class = "row">
#         <div class="float-left">
#                 <div class="col-md-4 dropDownList-padding-0">
#                     <link href="resources/js/support/select2/select2.min.css" rel="stylesheet" />
# <link href="resources/js/select2/select2Utild2178e7916b7389bbf38de58bb712713af78f498.css" rel="stylesheet" />
# <script src="resources/js/support/select2/select2.min.js"></script>
# <script src="resources/js/select2/select2Utild2178e7916b7389bbf38de58bb712713af78f498.js"></script>
# <script src="resources/js/simpleView/dropdownListsd2178e7916b7389bbf38de58bb712713af78f498.js"></script>
# <script>viewObjects["dropdowns"] = [{"selectedOptionIndex":0,"dropDownOptions":[{"id":"1.2","text":"Canada"},{"id":"1.3","text":"Newfoundland and Labrador"},{"id":"1.5","text":"Prince Edward Island"},{"id":"1.7","text":"Nova Scotia"},{"id":"1.9","text":"New Brunswick"},{"id":"1.11","text":"Quebec"},{"id":"1.14","text":"Ontario"},{"id":"1.18","text":"Manitoba"},{"id":"1.20","text":"Saskatchewan"},{"id":"1.23","text":"Alberta"},{"id":"1.26","text":"British Columbia"},{"id":"1.29","text":"Whitehorse, Yukon"},{"id":"1.30","text":"Yellowknife, Northwest Territories"},{"id":"1.31","text":"Iqaluit, Nunavut"}]}];</script>
#
#
# <div class = "tv-sp-dropdowns-container" id="dropdowns-container">
#     <div class="col-md-12 mrgn-btm-0 mrgn-lft-0 dropDownList-padding-0" style="margin-bottom:0.5em;">
#             <label class="pickMembersLabel" for="pickMembers[0]"
#                    title="Geography">
#                 Geography :
#                 </label>
#             <!-- dropdown menus-->
#             <select id="dropDownInput0"
#                     class="form-control form-input form-inline"
#                     name="pickMembers[0]"
#                     style="width:95%;margin-right:0.5em;height:2.3em;border-radius:3px"
#                     title="Geography dropdown menu">
#             </select>
#         </div>
#     </div></div>
#             </div>
#         <div class = "tv-sp-timeFrame-container" id="timeFrameContainer">
#                 <div class="form-inline">
#                     <label for="timeFrame">
#                         Reference period</label>
#                     <div id="timeFrame">
#                         <label for="startMonth">
#     From:</label>
#
# <select name="cubeTimeFrame.startMonth" id="startMonth" class="form-control" required="required">
#     <option value="01">January</option>
#     <option value="02">February</option>
#     <option value="03" selected="selected">March</option>
#     <option value="04">April</option>
#     <option value="05">May</option>
#     <option value="06">June</option>
#     <option value="07">July</option>
#     <option value="08">August</option>
#     <option value="09">September</option>
#     <option value="10">October</option>
#     <option value="11">November</option>
#     <option value="12">December</option>
#
#
# </select>
#
# <label for="startYear" class="wb-invisible">
#     start year</label>
# <select name="cubeTimeFrame.startYear" id="startYear" class="form-control" aria-label="">
#     <option value="1914">1914</option>
#     <option value="1915">1915</option>
#     <option value="1916">1916</option>
#     <option value="1917">1917</option>
#     <option value="1918">1918</option>
#     <option value="1919">1919</option>
#     <option value="1920">1920</option>
#     <option value="1921">1921</option>
#     <option value="1922">1922</option>
#     <option value="1923">1923</option>
#     <option value="1924">1924</option>
#     <option value="1925">1925</option>
#     <option value="1926">1926</option>
#     <option value="1927">1927</option>
#     <option value="1928">1928</option>
#     <option value="1929">1929</option>
#     <option value="1930">1930</option>
#     <option value="1931">1931</option>
#     <option value="1932">1932</option>
#     <option value="1933">1933</option>
#     <option value="1934">1934</option>
#     <option value="1935">1935</option>
#     <option value="1936">1936</option>
#     <option value="1937">1937</option>
#     <option value="1938">1938</option>
#     <option value="1939">1939</option>
#     <option value="1940">1940</option>
#     <option value="1941">1941</option>
#     <option value="1942">1942</option>
#     <option value="1943">1943</option>
#     <option value="1944">1944</option>
#     <option value="1945">1945</option>
#     <option value="1946">1946</option>
#     <option value="1947">1947</option>
#     <option value="1948">1948</option>
#     <option value="1949">1949</option>
#     <option value="1950">1950</option>
#     <option value="1951">1951</option>
#     <option value="1952">1952</option>
#     <option value="1953">1953</option>
#     <option value="1954">1954</option>
#     <option value="1955">1955</option>
#     <option value="1956">1956</option>
#     <option value="1957">1957</option>
#     <option value="1958">1958</option>
#     <option value="1959">1959</option>
#     <option value="1960">1960</option>
#     <option value="1961">1961</option>
#     <option value="1962">1962</option>
#     <option value="1963">1963</option>
#     <option value="1964">1964</option>
#     <option value="1965">1965</option>
#     <option value="1966">1966</option>
#     <option value="1967">1967</option>
#     <option value="1968">1968</option>
#     <option value="1969">1969</option>
#     <option value="1970">1970</option>
#     <option value="1971">1971</option>
#     <option value="1972">1972</option>
#     <option value="1973">1973</option>
#     <option value="1974">1974</option>
#     <option value="1975">1975</option>
#     <option value="1976">1976</option>
#     <option value="1977">1977</option>
#     <option value="1978">1978</option>
#     <option value="1979">1979</option>
#     <option value="1980">1980</option>
#     <option value="1981">1981</option>
#     <option value="1982">1982</option>
#     <option value="1983">1983</option>
#     <option value="1984">1984</option>
#     <option value="1985">1985</option>
#     <option value="1986">1986</option>
#     <option value="1987">1987</option>
#     <option value="1988">1988</option>
#     <option value="1989">1989</option>
#     <option value="1990">1990</option>
#     <option value="1991">1991</option>
#     <option value="1992">1992</option>
#     <option value="1993">1993</option>
#     <option value="1994">1994</option>
#     <option value="1995">1995</option>
#     <option value="1996">1996</option>
#     <option value="1997">1997</option>
#     <option value="1998">1998</option>
#     <option value="1999">1999</option>
#     <option value="2000">2000</option>
#     <option value="2001">2001</option>
#     <option value="2002">2002</option>
#     <option value="2003">2003</option>
#     <option value="2004">2004</option>
#     <option value="2005">2005</option>
#     <option value="2006">2006</option>
#     <option value="2007">2007</option>
#     <option value="2008">2008</option>
#     <option value="2009">2009</option>
#     <option value="2010">2010</option>
#     <option value="2011">2011</option>
#     <option value="2012">2012</option>
#     <option value="2013">2013</option>
#     <option value="2014">2014</option>
#     <option value="2015">2015</option>
#     <option value="2016">2016</option>
#     <option value="2017">2017</option>
#     <option value="2018">2018</option>
#     <option value="2019">2019</option>
#     <option value="2020">2020</option>
#     <option value="2021">2021</option>
#     <option value="2022">2022</option>
#     <option value="2023">2023</option>
#     <option value="2024" selected="selected">2024</option>
#
#
# </select>
#
# <label for="endMonth">
#     To:</label>
#
# <label for="" class="wb-invisible">
#     </label>
#
# <select name="cubeTimeFrame.endMonth" id="endMonth" class="form-control" required="required">
#     <option value="01">January</option>
#     <option value="02">February</option>
#     <option value="03">March</option>
#     <option value="04">April</option>
#     <option value="05">May</option>
#     <option value="06">June</option>
#     <option value="07" selected="selected">July</option>
#     <option value="08">August</option>
#     <option value="09">September</option>
#     <option value="10">October</option>
#     <option value="11">November</option>
#     <option value="12">December</option>
#
#
# </select>
#
# <label for="endYear" class="wb-invisible">
#     ca.statcan.tableviewer.web.hiddenlabel.timeframeRange.endYear</label>
# <select name="cubeTimeFrame.endYear" id="endYear" class="form-control">
#     <option value="1914">1914</option>
#     <option value="1915">1915</option>
#     <option value="1916">1916</option>
#     <option value="1917">1917</option>
#     <option value="1918">1918</option>
#     <option value="1919">1919</option>
#     <option value="1920">1920</option>
#     <option value="1921">1921</option>
#     <option value="1922">1922</option>
#     <option value="1923">1923</option>
#     <option value="1924">1924</option>
#     <option value="1925">1925</option>
#     <option value="1926">1926</option>
#     <option value="1927">1927</option>
#     <option value="1928">1928</option>
#     <option value="1929">1929</option>
#     <option value="1930">1930</option>
#     <option value="1931">1931</option>
#     <option value="1932">1932</option>
#     <option value="1933">1933</option>
#     <option value="1934">1934</option>
#     <option value="1935">1935</option>
#     <option value="1936">1936</option>
#     <option value="1937">1937</option>
#     <option value="1938">1938</option>
#     <option value="1939">1939</option>
#     <option value="1940">1940</option>
#     <option value="1941">1941</option>
#     <option value="1942">1942</option>
#     <option value="1943">1943</option>
#     <option value="1944">1944</option>
#     <option value="1945">1945</option>
#     <option value="1946">1946</option>
#     <option value="1947">1947</option>
#     <option value="1948">1948</option>
#     <option value="1949">1949</option>
#     <option value="1950">1950</option>
#     <option value="1951">1951</option>
#     <option value="1952">1952</option>
#     <option value="1953">1953</option>
#     <option value="1954">1954</option>
#     <option value="1955">1955</option>
#     <option value="1956">1956</option>
#     <option value="1957">1957</option>
#     <option value="1958">1958</option>
#     <option value="1959">1959</option>
#     <option value="1960">1960</option>
#     <option value="1961">1961</option>
#     <option value="1962">1962</option>
#     <option value="1963">1963</option>
#     <option value="1964">1964</option>
#     <option value="1965">1965</option>
#     <option value="1966">1966</option>
#     <option value="1967">1967</option>
#     <option value="1968">1968</option>
#     <option value="1969">1969</option>
#     <option value="1970">1970</option>
#     <option value="1971">1971</option>
#     <option value="1972">1972</option>
#     <option value="1973">1973</option>
#     <option value="1974">1974</option>
#     <option value="1975">1975</option>
#     <option value="1976">1976</option>
#     <option value="1977">1977</option>
#     <option value="1978">1978</option>
#     <option value="1979">1979</option>
#     <option value="1980">1980</option>
#     <option value="1981">1981</option>
#     <option value="1982">1982</option>
#     <option value="1983">1983</option>
#     <option value="1984">1984</option>
#     <option value="1985">1985</option>
#     <option value="1986">1986</option>
#     <option value="1987">1987</option>
#     <option value="1988">1988</option>
#     <option value="1989">1989</option>
#     <option value="1990">1990</option>
#     <option value="1991">1991</option>
#     <option value="1992">1992</option>
#     <option value="1993">1993</option>
#     <option value="1994">1994</option>
#     <option value="1995">1995</option>
#     <option value="1996">1996</option>
#     <option value="1997">1997</option>
#     <option value="1998">1998</option>
#     <option value="1999">1999</option>
#     <option value="2000">2000</option>
#     <option value="2001">2001</option>
#     <option value="2002">2002</option>
#     <option value="2003">2003</option>
#     <option value="2004">2004</option>
#     <option value="2005">2005</option>
#     <option value="2006">2006</option>
#     <option value="2007">2007</option>
#     <option value="2008">2008</option>
#     <option value="2009">2009</option>
#     <option value="2010">2010</option>
#     <option value="2011">2011</option>
#     <option value="2012">2012</option>
#     <option value="2013">2013</option>
#     <option value="2014">2014</option>
#     <option value="2015">2015</option>
#     <option value="2016">2016</option>
#     <option value="2017">2017</option>
#     <option value="2018">2018</option>
#     <option value="2019">2019</option>
#     <option value="2020">2020</option>
#     <option value="2021">2021</option>
#     <option value="2022">2022</option>
#     <option value="2023">2023</option>
#     <option value="2024" selected="selected">2024</option>
#
#
# </select>
#
# </div>
#                 </div>
#             </div>
#             <input type="hidden" id= "refPeriods" name="referencePeriods" value=""/>
#         </div>
#
#     <div class = "row tv-sp-applyButton-container">
#         <div class="col-md-9  mrgn-lft-0 divLeft">
#             <button id="applyButton" type="button" class="btn btn-primary tbl-loader">
#                 Apply</button>
#         </div>
#     </div>
# </details>
# <script src="resources/js/custom/vue.min.js"></script>
#
#     <div class="clear"></div>
# <div class="pull-right" hidden id="downloadButton" style="margin-bottom: 0.5em">
#     <a href="/t1/tbl1/en/cv.action?pid=1810000401" class="btn btn-primary ui-link tbl-loader" title="Use this dataset to add/remove data" role="button"><i class="fa fa-pencil"></i>
#         Add/Remove data</a><a href="#centred-popup" style="text-decoration:none" aria-controls="centred-popup" class="wb-lbx"
#        role="button" aria-label="Add/Remove data help">
#         <span style="margin-top:0.5em;color:gray;" class="glyphicon glyphicon-info-sign" aria-hidden="true">
#         </span>
#     </a>
#
#     <!-- i ball popup -->
#     <section id="centred-popup" class="mfp-hide modal-dialog modal-content overlay-def">
#         <header class="modal-header">
#             <h2 class="modal-title">
#                 Add/Remove data help</h2>
#         </header>
#         <div class="modal-body">
#             Select your items to create your customized table.</div>
#     </section>
#
#     <!--
# Download overlay:
# Must have ID called.
# Must be included to page its used on.
#
# Explanation:
# Displays an overlay with options regarding downloads of table viewer files.
# Also displays the Download button.
# -->
#
# <!-- Download button -->
# <a id="downloadOverlayLink" aria-controls="centred-popup" onclick="openDownloadOverlay();"
#    class="btn btn-default" style="margin-top: 0.25em; margin-left: 1em;"
#    role="button"
#    title="Download options">
#     <span class="glyphicon glyphicon-save"></span>
#     Download options</a>
#
# <section id="downloadButtonOverlay" class="mfp-hide modal-dialog modal-content overlay-def">
#     <header class="modal-header">
#         <h2 class="modal-title">
#             Download options</h2>
#     </header>
#     <div class="modal-body">
#         <div class="row" style="padding-left: 15px">
#             <div class="btn-group-vertical col-xs-12" role="group">
#                 <div class="row">
#                     <a id="downloadAsDisplay" href="#?pid=18100004&file=1810000401-eng.csv" class="btn btn-default col-xs-11" title="18100004 Download as displayed" data-gc-analytics-download="statcan"><div class="row" style="display:inline-flex; width:105%">
#                             <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                 <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                             </div>
#                             <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                 <div class="row">
#                                     <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                             CSV</h3>
#                                 </div>
#                                 <div class="row" id = "csvSizeLabel">
#                                     <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                             Download as displayed&nbsp;{{ csvSize }}kB.
#                                     </p>
#                                 </div>
#                             </div>
#                         </div></a></div>
#
#                 <div class="row">
#                     <a id="downloadWithoutSymbols" href="#?pid=18100004&file=1810000401-noSymbol.csv" class="btn btn-default col-xs-11" title="18100004 Download as displayed (excluding accompanying symbols)" data-gc-analytics-download="statcan"><div class="row" style="display:inline-flex; width:105%">
#                             <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                 <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                             </div>
#                             <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                 <div class="row">
#                                     <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                             CSV</h3>
#                                 </div>
#                                 <div class="row">
#                                     <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                                 Download as displayed&nbsp;(excluding accompanying symbols).
#                                         </p>
#                                     </div>
#                             </div>
#                         </div></a></div>
#
#                 <div class="row">
#                     <a id="downloadSymbolsSeparate" href="#?pid=18100004&file=1810000401-symbolsSeparate.csv" class="btn btn-default col-xs-11" title="18100004 Download as displayed (symbols separate)" data-gc-analytics-download="statcan"><div class="row" style="display:inline-flex; width:105%">
#                             <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                 <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                             </div>
#                             <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                 <div class="row">
#                                     <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                             CSV</h3>
#                                 </div>
#                                 <div class="row">
#                                     <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                                 Download as displayed&nbsp;(symbols separate).
#                                         </p>
#                                     </div>
#                             </div>
#                         </div></a></div>
#
#                 <div class="row" id="downloadSelectedData">
#                         <a id="downloadDbLoading" href="/t1/tbl1/en/dtl!downloadDbLoadingData-nonTraduit.action?pid=1810000401&amp;latestN=5&amp;startDate=&amp;endDate=&amp;csvLocale=en&amp;selectedMembers=%5B%5B2%5D%2C%5B2%2C3%2C79%2C96%2C139%2C176%2C184%2C201%2C219%2C256%2C274%2C282%2C285%2C287%2C288%5D%5D&amp;checkedLevels=" class="btn btn-default col-xs-11" title="18100004 Download selected data (for database loading)" data-gc-analytics-download="statcan"><div class="row" style="display:inline-flex; width:105%">
#                             <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                 <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                             </div>
#                             <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                 <div class="row">
#                                     <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                             CSV</h3>
#                                 </div>
#                                 <div class="row">
#                                     <p id="dbLoadingDataTitle" class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                             Download selected data&nbsp;(for database loading).
#                                     </p>
#                                 </div>
#                                 <div class="row">
#                                     <p id="divErrorMessage"></p>
#                                 </div>
#                             </div>
#                         </div></a></div>
#
#                 <div class="row">
#                     <a href="/t1/tbl1/en/dtl!downloadCubeMetaData-nonTraduit.action?pid=1810000401&amp;csvLocale=en" class="btn btn-default col-xs-11" title="18100004 Download cube metadata information" data-gc-analytics-download="statcan"><div class="row" style="display:inline-flex; width:105%">
#                             <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                 <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                             </div>
#                             <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                 <div class="row">
#                                     <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                             CSV</h3>
#                                 </div>
#                                 <div class="row">
#                                     <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                             Download cube metadata information, ~50kB.
#                                     </p>
#                                 </div>
#                             </div>
#                         </div></a></div>
#
#                 <div class="row">
#                         <a data-gc-analytics-download='statcan' href="https://www150.statcan.gc.ca/n1/tbl/csv/18100004-eng.zip"
#                            class="btn btn-default col-xs-11" title="18100004Download entire table">
#                             <div class="row" style="display:inline-flex; width:105%">
#                                 <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                     <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                                 </div>
#                                 <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                     <div class="row">
#                                         <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px">
#                                                 CSV</h3>
#                                     </div>
#                                     <div class="row">
#                                         <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">
#                                             Download entire table
#                                                 "Consumer Price Index, monthly, not seasonally adjusted".
#                                             </p>
#                                     </div>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                     <div class="row">
#                             <a data-gc-analytics-download='statcan' href="https://www150.statcan.gc.ca/n1/tbl/sdmx/18100004-SDMX.zip" class="btn btn-default col-xs-11"
#                                title="18100004Download entire table">
#                                 <div class="row" style="display:inline-flex; width:105%">
#                                     <div class="col-xs-2" style="margin-top: 4px; width:12.5%; padding-right: 45px">
#                                         <span class="fa fa-file fa-4x" aria-hidden="true"></span>
#                                     </div>
#                                     <div class="col-xs-10" style="padding-top:5px; margin-left: 15px">
#                                         <div class="row">
#                                             <h3 class="pull-left" style="margin-top: 9px; margin-bottom: 9px; margin-left:5px; text-align:left">
#                                                 SDMX</h3>
#                                         </div>
#                                         <div class="row">
#                                             <p class="pull-left" style="margin-bottom: 9px; margin-left:5px; text-align:left">Download entire table.</p>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </a>
#                         </div>
#                     </div>
#         </div>
#         <div class="row" style="padding-left:15px">
#             Other data access options:&nbsp;
#             <a href="http://www.statcan.gc.ca/eng/developers?HPA=1" title="Developers" target="blank">Developers</a></div>
#     </div>
# </section>
#
# <script type='text/javascript'>
#     function calculateDbLoadingFileSize(selectedMembers, refPeriodObject) {
#         // Multiple each dimension's member length
#         var dimNum = selectedMembers.length;
#         var memMultiple = 1;
#         for (var i = 0; i < dimNum; i++) {
#             memMultiple *= selectedMembers[i].length;
#         }
#
#         var numRefPeriods;
#         if (refPeriodObject.latestN != 0) {
#             numRefPeriods = refPeriodObject.latestN;
#         }
#         else {
#             // Get the ref start and end
#             var startDate = new Date(refPeriodObject.startDate);
#             var endDate = new Date(refPeriodObject.endDate);
#             startDate.setTime( startDate.getTime() + startDate.getTimezoneOffset()*60*1000 );
#             endDate.setTime( endDate.getTime() + endDate.getTimezoneOffset()*60*1000 );
#
#             // get the right interval and divider for each type of frequency
#             var frequencyValue = 6;
#             numRefPeriods = numberOfReferencePeriods(startDate, endDate, frequencyValue)
#         }
#
#         // calcualte the size estimate for the db downloading CSV file
#         var sizeOfEstimate = memMultiple * numRefPeriods * 200 / 1000 ;
#         var sizeInKB = sizeOfEstimate.toFixed(2);
#
#         return sizeInKB;
#     }
#
#     // Setup Vue instance to set the CSV download as display file size
#     let csvSizeLine = new Vue({
#         el: "#csvSizeLabel",
#         data: {
#             csvSize: "0"
#         }
#     });
#
#
#     $(document).ready(function () {
#         // When the page is ready, show the download link
#         $("#downloadButton").show();
#
#         // Handle the hyperlink click event
#         $("#downloadAsDisplay").click(function (event) {
#             exportSimpleTableCSV.apply(this, [event, '1810000401-eng.csv', false, false]);
#         });
#
#         $("#downloadWithoutSymbols").click(function (event) {
#             exportSimpleTableCSV.apply(this, [event, '1810000401-noSymbol.csv', true, false]);
#         });
#
#         $("#downloadSymbolsSeparate").click(function (event) {
#             exportSimpleTableCSV.apply(this, [event, '1810000401-symbolsSeparate.csv', false, true]);
#         });
#
#         $("#download").click(function (event) {
#             var selectedMember;
#             var refPeriodObject = {latestN: 0, startDate: "", endDate: ""};
#
#             if (typeof action !== 'undefined' && action === "cv") {
#                 // console.log("Action Name is " + action);
#                 refPeriodObject = getCvRefPeriodInISOformat();
#                 selectedMember = JSON.parse(getJsTreeCheckedIds());
#             }
#             else
#             {
#                 // Multiple each dimension's member length
#                 selectedMember = [[2],[2,3,79,96,139,176,184,201,219,256,274,282,285,287,288]];
#                 refPeriodObject.startDate = "2024-03-01";
#                 refPeriodObject.endDate = "2024-07-01";
#             }
#             var sizeInKB = calculateDbLoadingFileSize(selectedMember, refPeriodObject);
#             // put the size in the anchor element
#             var loadingText = "Download selected data";
#             $("a#downloadDbLoading p").text(loadingText + ", " + sizeInKB + "kB.")
#         });
#
#         $("#downloadSelectedData").click(function (event) {
#
#             var isIE = false || !!document.documentMode;
#             var urlLength = 269
#
#             if (isIE && urlLength > 2083) {
#                 $("#divErrorMessage").text('IE could not process this request, please change your browser.');
#                 $("#divErrorMessage").css('color', 'red');
#             }
#         });
#
#     });
#
#     function openDownloadOverlay() {
#         $(document).trigger("open.wb-lbx", [
#             [
#                 {
#                     src: "#downloadButtonOverlay",
#                     type: "inline"
#                 }
#             ],
#             false,
#             [
#                 "Image 1"
#             ]
#         ]);
#     }
#
# </script>
# </div>
# <div class="clear"></div><p class="viewSubtitle">
#         Didn't find what you're looking for?<a href="#relatedTables" aria-controls="centred-popup" class="wb-lbx" role="button">
#             View related tables, including other calculations and frequencies</a>
#     </p>
#
#     <section id="relatedTables" class="mfp-hide modal-dialog modal-content overlay-def">
#         <header class="modal-header">
#             <h2 class="modal-title">
#                 View related tables, including other calculations and frequencies</h2>
#         </header>
#         <div class="modal-body">
#
#             <label class="control-label"><strong>
#                     Alternative view(s):</strong></label>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000402">Consumer Price Index by geography, all-items, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse, Yellowknife and Iqaluit (18-10-0004-02)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000403">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Food (18-10-0004-03)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000404">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Shelter (18-10-0004-04)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000405">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Household operations, furnishings and equipment (18-10-0004-05)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000406">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Clothing and footwear (18-10-0004-06)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
#                         <li>
#                             <!-- TODO bechric Could make this a custom tag and add it to tableviewer.tld if warranted.  But seems negligible for now. -->
#                             <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000407">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Transportation (18-10-0004-07)</a>
#                             <br>
#                             <em>Frequency:</em> Monthly</li>
#                     </ul>
#                 <ul>
# ...
#     });
#
#     window.addEventListener("resize", function() {
#         setContainerDimensions();
#     });
#
#     let errMsgNoData = new Vue({
#         el: "#error-message-no-data",
#         data: {
#             errorText: ""
#         }
#     });
#
# </script><div id="citeInfo">
# <strong>How to cite: </strong>
#
#
#
# Statistics Canada.
# <a href="/t1/tbl1/en/tv.action?pid=1810000401"><span>Table</span>
#         18-10-0004-01&nbsp;
#         Consumer Price Index, monthly, not seasonally adjusted</a></div>
#
# <div id="doiInfo">
#
#     <strong><span>DOI: </span></strong>
#         <a href="https://doi.org/10.25318/1810000401-eng"><span>https://doi.org/10.25318/1810000401-eng</span></a><script type="application/ld+json">
#     {
#         "@context": "http://schema.org/",
#         "@type": "Dataset",
#         "@id": "https://doi.org/10.25318/1810000401-eng",
#         "name": "Consumer Price Index, monthly, not seasonally adjusted",
#         "alternateName": "1810000401",
#         "description": "Monthly indexes for major components and special aggregates of the Consumer Price Index (CPI), not seasonally adjusted, for Canada, provinces, Whitehorse, Yellowknife and Iqaluit. Data are presented for the current month and previous four months. The base year for the index is 2002=100.",
#         "url": "www150.statcan.gc.ca/tbl1/en/tv.action?pid=1810000401",
#         "sameAs": "www150.statcan.gc.ca/tbl1/fr/tv.action?pid=1810000401",
#         "keywords": "Municipal and local data",
#         "about": ["Consumer price indexes", "Economic impacts of COVID-19"],
#         "isBasedOn": "http://www23.statcan.gc.ca/imdb/p2SV.pl?Function=getSurvey&SDDS=2301",
#         "datePublished": "2024-08-20",
#         "spatialCoverage": "Canada",
#         "publisher": {
#             "@type": "Organization",
#             "additionalType": "GovernmentOrganization",
#             "url": "http://www.statcan.gc.ca/eng/start",
#             "name": "Government of Canada, Statistics Canada",
#             "sameAs":  ["https://en.wikipedia.org/wiki/Statistics_Canada", "https://twitter.com/statcan_eng", "https://www.facebook.com/StatisticsCanada/"]
#         }
#     }
# </script>
# </div>
#
# <div class="clear"></div>
# <br/>
# <div class="panel-pane pane-ndm-crosswalk mrgn-bttm-lg"><div class="pane-content"><div class=""><h2>Related information</h2><details><summary>Replaces</summary><div class="item-list"><ul><li><a href="https://www150.statcan.gc.ca/n1/en/catalogue/62-001-X" title="The Consumer Price Index">The Consumer Price Index</a></li>
# </ul></div></details><details><summary>Source (Surveys and statistical programs)</summary><div class="item-list"><ul><li><a href="http://www23.statcan.gc.ca/imdb/p2SV.pl?Function=getSurvey&amp;SDDS=2301" title="Consumer Price Index">Consumer Price Index</a></li>
# </ul></div></details><details><summary>Related products</summary><h3>Data</h3><div class="item-list"><ul><li>Data Visualization: <a href="https://www150.statcan.gc.ca/n1/pub/71-607-x/71-607-x2020009-eng.htm" title="Canadian Economic Dashboard and COVID-19">Canadian Economic Dashboard and COVID-19</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000402" title="Consumer Price Index by geography, all-items, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse, Yellowknife and Iqaluit">Consumer Price Index by geography, all-items, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse, Yellowknife and Iqaluit</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000413" title="Consumer Price Index by product group, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse, Yellowknife and Iqaluit">Consumer Price Index by product group, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse, Yellowknife and Iqaluit</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000412" title="Consumer Price Index by product group, monthly, percentage change, not seasonally adjusted, provincial cities">Consumer Price Index by product group, monthly, percentage change, not seasonally adjusted, provincial cities</a></li>
# <li>Data Visualization: <a href="https://www150.statcan.gc.ca/n1/pub/71-607-x/71-607-x2018016-eng.htm" title="Consumer Price Index Data Visualization Tool">Consumer Price Index Data Visualization Tool</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000501" title="Consumer Price Index, annual average, not seasonally adjusted">Consumer Price Index, annual average, not seasonally adjusted</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000411" title="Consumer Price Index, by geography, monthly, percentage change, not seasonally adjusted, provinces, Whitehorse and Yellowknife">Consumer Price Index, by geography, monthly, percentage change, not seasonally adjusted, provinces, Whitehorse and Yellowknife</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000410" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife - Alcoholic beverages, tobacco products and recreational cannabis">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife - Alcoholic beverages, tobacco products and recreational cannabis</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000406" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Clothing and footwear">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Clothing and footwear</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000403" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Food">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Food</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000408" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Health and personal care">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Health and personal care</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000405" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Household operations, furnishings and equipment">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Household operations, furnishings and equipment</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000409" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Recreation, education and reading">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Recreation, education and reading</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000404" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Shelter">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Shelter</a></li>
# <li>Tables: <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000407" title="Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Transportation">Consumer Price Index, monthly, percentage change, not seasonally adjusted, Canada, provinces, Whitehorse and Yellowknife — Transportation</a></li>
# <li>Data Visualization: <a href="https://www150.statcan.gc.ca/n1/pub/71-607-x/71-607-x2018014-eng.htm" title="Housing Market Indicators">Housing Market Indicators</a></li>
# </ul></div><h3>Analysis</h3><div class="item-list"><ul><li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2021004-eng.htm" title="A new approach for estimating the Computer equipment, Software and Supplies Index in the Consumer Price Index">A new approach for estimating the Computer equipment, Software and Supplies Index in the Consumer Price Index</a></li>
# <li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2020014-eng.htm" title="An analysis of recent issues faced by the Canadian pork industry">An analysis of recent issues faced by the Canadian pork industry</a></li>
# <li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2022014-eng.htm" title="Behind the Numbers: What’s Causing Growth in Food Prices">Behind the Numbers: What’s Causing Growth in Food Prices</a></li>
# <li>Stats in brief: <a href="https://www150.statcan.gc.ca/n1/daily-quotidien/240820/dq240820a-eng.htm" title="Consumer Price Index July 2024">Consumer Price Index July 2024</a></li>
# <li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2023004-eng.htm" title="Corporate profitability and inflation: 2017 to 2022">Corporate profitability and inflation: 2017 to 2022</a></li>
# <li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/45-28-0001/2020001/article/00086-eng.htm" title="COVID-19 and the beef supply chain: An overview">COVID-19 and the beef supply chain: An overview</a></li>
# <li>Articles and reports: <a href="https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2023001-eng.htm" title="Measuring the price of digital computing equipment and devices in the Consumer Price Index">Measuring the price of digital computing equipment and devices in the Consumer Price Index</a></li>
# <li>Stats in brief: <a href="https://www150.statcan.gc.ca/n1/pub/11-627-m/11-627-m2022068-eng.htm" title="The rise in prices for wheat-based food products">The rise in prices for wheat-based food products</a></li>
# </ul></div></details><details><summary>Subjects and keywords</summary><h3>Subjects</h3><div class="item-list"><ul><li><a href="https://www.statcan.gc.ca/en/subjects-start/prices_and_price_indexes" title="Prices and price indexes">Prices and price indexes</a><ul><li><a href="https://www150.statcan.gc.ca/n1/en/subjects/prices_and_price_indexes/consumer_price_indexes" title="Consumer price indexes">Consumer price indexes</a><ul></ul></li></ul></li>
# <li><a href="https://www.statcan.gc.ca/en/subjects-start/society_and_community" title="Society and community">Society and community</a><ul><li><a href="https://www150.statcan.gc.ca/n1/en/subjects/society_and_community/coronavirus" title="Coronavirus">Coronavirus</a><ul><li><a href="https://www150.statcan.gc.ca/n1/en/subjects/society_and_community/coronavirus/economic_impacts_of_covid19" title="Economic impacts of COVID-19">Economic impacts of COVID-19</a></li></ul></li></ul></li>
# </ul></div><h3>Keywords</h3><div class="item-list"><ul><li><a href="https://www150.statcan.gc.ca/n1/en/metadata?keywords_terms=municipal_and_local_data">Municipal and local data</a></li>
# </ul></div></details></div></div></div></form>
#
#
# <script type="text/javascript">
#     let contextPath = '/tbl1';
# </script>
# <div class="pagedetails">
# 	<div class="row">
# 		<div class="col-sm-6 col-lg-4 mrgn-tp-sm">
# 			<details class="brdr-0">
# 				<summary class="btn btn-default text-center">Report a problem on this page</summary>
# 				<div class="clearfix"></div>
# 				<div class="well row">
# 					<div class="gc-rprt-prblm">
# 						<div class="gc-rprt-prblm-frm gc-rprt-prblm-tggl">
# 							<p>Is something not working? Is there information outdated? Can't find what you're looking for?</p>
# 							<p>Please <a href="https://www.statcan.gc.ca/eng/reference/refcentre/index?MM=RAP">contact us</a> and let us know how we can help you.</p>
# 							<p><a href="https://www.statcan.gc.ca/eng/reference/privacy?MM=RAP">Privacy notice</a></p>
# 						</div>
# 					</div>
# 				</div>
# 			</details>
# 		</div>
# 		<!-- Share button -->
# 		<div class="wb-share col-sm-4 col-md-3 col-sm-offset-2 col-md-offset-4 col-lg-offset-5" data-wb-share='{"lnkClass": "btn btn-default btn-block"}'></div>
# 		<!-- END Share button -->
# 	</div>
# 	<dl id="wb-dtmd">
# 		<dt>Date modified:&#32;</dt>
# 		<dd><time property="dateModified">2024-09-12</time></dd>
# 	</dl>
# </div>
# </main><footer role="contentinfo" id="wb-info">
# 	<div class="landscape">
# 		<nav role="navigation" class="container wb-navcurr">
# 			<h2 class="wb-inv">About government</h2>
# 			<ul class="list-unstyled colcount-sm-2 colcount-md-3">
# 				<li><a href="https://www.statcan.gc.ca/eng/reference/refcentre/index?MM=1">Contact us</a></li>
# 				<li><a href="https://www.canada.ca/en/government/dept.html">Departments and agencies</a></li>
# 				<li><a href="https://www.canada.ca/en/government/publicservice.html">Public service and military</a></li>
# 				<li><a href="https://www.canada.ca/en/news.html">News</a></li>
# 				<li><a href="https://www.canada.ca/en/government/system/laws.html">Treaties, laws and regulations</a></li>
# 				<li><a href="https://www.canada.ca/en/transparency/reporting.html">Government-wide reporting</a></li>
# 				<li><a href="http://pm.gc.ca/eng">Prime Minister</a></li>
# 				<li><a href="https://www.canada.ca/en/government/system.html">How government works</a></li>
# 				<li><a href="http://open.canada.ca/en/">Open government</a></li>
# 			</ul>
# 		</nav>
# 	</div>
# 	<div class="brand">
# 		<div class="container">
# 			<div class="row">
# 				<nav class="col-md-10 ftr-urlt-lnk">
# 					<h2 class="wb-inv">About this site</h2>
# 					<ul>
# 						<li><a href="https://www.canada.ca/en/social.html">Social media</a></li>
# 						<li><a href="https://www.canada.ca/en/mobile.html">Mobile applications</a></li>
# 						<li><a href="https://www.canada.ca/en/government/about.html">About Canada.ca</a></li>
# 						<li><a href="https://www.statcan.gc.ca/eng/reference/terms-conditions?MM=1">Terms and conditions</a></li>
# 						<li><a href="https://www.statcan.gc.ca/eng/reference/privacy?MM=1">Privacy</a></li>
# 					</ul>
# 				</nav>
# 				<div class="col-xs-6 visible-sm visible-xs tofpg">
# 					<a href="#wb-cont">Top of Page <span class="glyphicon glyphicon-chevron-up"></span></a>
# 				</div>
# 				<div class="col-xs-6 col-md-2 text-right">
# 					<img src="/t1/wet-boew4b/assets/wmms-blk.svg" alt="Symbol of the Government of Canada"><span class="wb-inv">Government of Canada</span>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </footer>
#
# <!--[if gte IE 9 | !IE ]><!-->
# <script src="/t1/wet-boew4b/js/wet-boew.min.js"></script>
# <script src="/t1/wet-boew4b/js/theme.min.js"></script>
# <!--<![endif]-->
# <!--[if lt IE 9]>
# <script src="/t1/wet-boew4b/js/ie8-wet-boew2.min.js"></script>
# <![endif]-->
# <!-- LiveZilla Script BEGIN -->
# <script type="text/javascript">
# 	var lz_data = {overwrite:false,language:'en'};
# </script>
# <script type="text/javascript" id="c2e78f4994aa191dd320f0f115f8fd70" src="https://www.statcan.gc.ca/livechat/script.php?id=c2e78f4994aa191dd320f0f115f8fd70" defer=""></script>
# <!-- LiveZilla Script END -->
# <!-- InvitationManager -->
# <script src="/t1/wet-boew4b/invitation-manager/Overlay.js"></script>
# <script src="/t1/wet-boew4b/invitation-manager/InvitationManager.js"></script>
# <!-- End InvitationManager -->
# <script type="text/javascript">_satellite.pageBottom();</script></body>
# </html>
